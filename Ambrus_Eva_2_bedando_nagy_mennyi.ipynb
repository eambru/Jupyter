# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#1. feladat
#Create a 100 elements random array and visualize its content using matplotlib
randomm = np.random.random(101)
#print(randomm)
x=range(len(randomm))
plt.plot(x,randomm)

# %%
#2. feladat
#Make a scatter plot of sepal_length vs sepal_width using Matplotlib. Label the axes and give the plot a title
import os
file_path = "/content/drive/MyDrive/Colab Notebooks/Iris_Data.csv"
print(file_path)
df = pd.read_csv(file_path)
plt.plot(df.sepal_length, df.sepal_width, ls='', marker='o')
plt.title('Évi adatai')
plt.xlabel('x axis label')
plt.ylabel('y axis label')
# Out:
# /content/drive/MyDrive/Colab Notebooks/Iris_Data.csv
# Text(0, 0.5, 'y axis label')

# %%
#3. feladat
#Make a histogram for each feature (petal_width, petal_length, sepal_width, sepal_length) overlayed
plt.hist(df.petal_width, bins=25)
plt.hist(df.petal_length, bins=25)
plt.hist(df.sepal_width, bins=25)
plt.hist(df.sepal_length, bins=25)
# Out:
# (array([ 4.,  1.,  6.,  5., 16.,  9.,  5.,  6.,  7., 14.,  7.,  9.,  6.,
#         13.,  7.,  7.,  8.,  3.,  5.,  1.,  4.,  1.,  1.,  4.,  1.]),
#  array([4.3  , 4.444, 4.588, 4.732, 4.876, 5.02 , 5.164, 5.308, 5.452,
#         5.596, 5.74 , 5.884, 6.028, 6.172, 6.316, 6.46 , 6.604, 6.748,
#         6.892, 7.036, 7.18 , 7.324, 7.468, 7.612, 7.756, 7.9  ]),
#  <BarContainer object of 25 artists>)

# %%
#4.feladat
#Using Pandas, make a boxplot of each petal and sepal measurement
sns.boxplot(data=df[['petal_width' , 'petal_length' , 'sepal_width' , 'sepal_length']])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
